# %% [markdown]
# # 04 — Attribute importance (SHAP + LIME)

# %%
TRACK = "hourly"

import sys
from pathlib import Path
root = Path("/content/Final") if Path("/content/Final").exists() else Path("..").resolve()
sys.path.insert(0, str(root))

from src.config import load_config
from src.xai_attributes import run_attributes_for_windows
from src.xai_compare import compare_all
from src.paths import sync_to_drive

cfg = load_config(track=TRACK)
run_attributes_for_windows(cfg)
compare_all(cfg)
sync_to_drive(cfg)

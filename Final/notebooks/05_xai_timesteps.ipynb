# %% [markdown]
# # 05 — Time-step importance (Integrated Gradients + memory horizon)

# %%
TRACK = "hourly"

import sys
from pathlib import Path
root = Path("/content/Final") if Path("/content/Final").exists() else Path("..").resolve()
sys.path.insert(0, str(root))

from src.config import load_config
from src.xai_timesteps import run_timesteps_for_windows
from src.paths import sync_to_drive

cfg = load_config(track=TRACK)
run_timesteps_for_windows(cfg)
sync_to_drive(cfg)
